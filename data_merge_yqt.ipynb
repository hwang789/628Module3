# %%
import json
import pandas as pd

# %%
data_business = pd.read_json('business.json', lines = True)
data_tip = pd.read_json('tip.json', lines = True)
# data_review = pd.read_json('review.json', lines = True)

# %%
data_business.head(10)
# Out:
#               business_id                             name  \
# 0  1SWheh84yJXfytovILXOAQ       Arizona Biltmore Golf Club
# 1  QXAEGFB4oINsVuTFxEYKFQ       Emerald Chinese Restaurant
# 2  gnKjwL_1w79qoiV3IC_xQQ      Musashi Japanese Restaurant
# 3  xvX2CttrVhyG2z1dFg_0xw  Farmers Insurance - Paul Lorenz
# 4  HhyxOkGAM07SRYtlQ4wMFQ              Queen City Plumbing
# 5  68dUKd8_8liJ7in4aWOSEA                    The UPS Store
# 6  5JucpCfHZltJh5r1JabjDg                 Edgeworxx Studio
# 7  gbQN7vr_caG_A1ugSmGhWg                        Supercuts
# 8  Y6iyemLX_oylRpnr38vgMA          Vita Bella Fine Day Spa
# 9  4GBVPIYRvzGh4K4TkRQ_rw              Options Salon & Spa
#
#                                              address           city state  \
# 0                        2818 E Camino Acequia Drive        Phoenix    AZ
# 1                               30 Eglinton Avenue W    Mississauga    ON
# 2                          10110 Johnston Rd, Ste 15      Charlotte    NC
# ...

# %%
data_tip.head(1)
# Out:
#                   user_id             business_id  \
# 0  UPw5DWs_b-e2JRBS-t37Ag  VaKXUpmWTTWDKbpJ3aQdMw
#
#                                                 text                date  \
# 0  Great for watching games, ufc, and whatever el... 2014-03-27 03:51:24
#
#    compliment_count
# 0                 0

# %%
pd.merge(data_business.head(5), data_tip.head(5), how = 'outer')
# Out:
#               business_id                             name  \
# 0  1SWheh84yJXfytovILXOAQ       Arizona Biltmore Golf Club
# 1  QXAEGFB4oINsVuTFxEYKFQ       Emerald Chinese Restaurant
# 2  gnKjwL_1w79qoiV3IC_xQQ      Musashi Japanese Restaurant
# 3  xvX2CttrVhyG2z1dFg_0xw  Farmers Insurance - Paul Lorenz
# 4  HhyxOkGAM07SRYtlQ4wMFQ              Queen City Plumbing
# 5  VaKXUpmWTTWDKbpJ3aQdMw                              NaN
# 6  OPiPeoJiv92rENwbq76orA                              NaN
# 7  5KheTjYPu1HcQzQFtm4_vw                              NaN
# 8  TkoyGi8J7YFjA6SbaRzrxg                              NaN
# 9  AkL6Ous6A1atZejfZXn1Bg                              NaN
#
#                           address         city state postal_code   latitude  \
# 0     2818 E Camino Acequia Drive      Phoenix    AZ       85016  33.522143
# 1            30 Eglinton Avenue W  Mississauga    ON     L5R 3E7  43.605499
# 2       10110 Johnston Rd, Ste 15    Charlotte    NC       28210  35.092564
# ...

# %%
data_business_tip = pd.merge(data_business, data_tip, how = 'outer')
data_all = pd.merge(data_review, data_business_tip, how = 'outer')

# %%
data_all.head(10)
